# %% [markdown]
# <img src="https://bit.ly/2VnXWr2" width="100" align="left">

# %% [markdown]
# # Rock, Paper & Scissors
#
# Let's play the famous game against our computer. You can check the rules [here](https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors).
#
# ## Task
# Create a program that imitates the playability of the well known game of rock, paper, scissors. Follow the guidelines provided.
#
# ## Tools
# 1. Loop: **for/while**
# 2. Functions: **input(), print()...**
# 3. Conditional statements: **if, elif, else**
# 4. Definition of functions. Modular programming
# 5. Import modules
#
# **To solve this challenge, the use of functions is recommended.**
#
# #### 1. Import the choice function of the random module.

# %%
from random import randint

# %% [markdown]
# #### 2. Create a list that includes the 3 possible gesture options of the game: 'rock', 'paper' or 'scissors'. Store the list in a variable called `gestures`.

# %%
# list of gestures
gestures = ['Rock', 'Paper', 'Scissors']

# %% [markdown]
# #### 3. Create a variable called `n_rounds` to store the maximum number of rounds to play in a game.
# Remember that the number of rounds must be odd: 1, 3, 5, ...

# %%
# define the number of rounds
n_rounds = 5

# %% [markdown]
# #### 4. Create a variable called `rounds_to_win` to store the number of rounds that a player must win to win the game.
# **Hint**: the value stored in `rounds_to_win` depends on the value of `n_rounds`.

# %%
# did this inside the main game function below

# %% [markdown]
# #### 5. Create two variables to store the number of rounds that the computer and the player have won. Call these variables `cpu_score` and `player_score`.

# %%
# did this inside the main game function below

# %% [markdown]
# #### 6. Define a function that randomly returns one of the 3 gesture options.
# You will use this function to simulate the gesture choice of the computer.

# %%
def cpu_choice():
    return gestures[randint(0, 2)]

# %% [markdown]
# #### 7. Define a function that asks the player which is the gesture he or she wants to show: 'rock', 'paper' or 'scissors'.
# The player should only be allowed to choose one of the 3 gesture options. If the player's choice is not rock, paper or scissors, keep asking until it is.

# %%
def player_choice():
    
    # set up a while loop that continues if input is invalid and breaks with a correct input.
    while True: 
        
        # get user input
        choice = input("Rock, Paper or Scissors?: ")
        
        # if the choice is not in the approved list
        if choice not in gestures:
            print("Hmmm not valid, try again please!")
            continue
        
        else:
            break
        
    return choice

# %% [markdown]
# #### 8. Define a function that checks who won a round.
# The function should return 0 if there is a tie, 1 if the computer wins and 2 if the player wins.

# %%
def round_winner(player, cpu):
    
    # print both choices
    print("You choose %s and Computer chooses %s" % (player, cpu))
    
    # check for ties
    if player == cpu:
        print("It's a tie!")
        return 0
    
    # check when player chose Rock
    elif player == 'Rock':
        if cpu == 'Paper':
            print("Paper covers Rock! Computer wins!")
            return 1
        else:
            print("Rock crushes Scissors! You win!")
            return 2
    
    # when the player chose Paper
    elif player == 'Paper':
        if cpu == 'Rock':
            print("Paper covers Rock! You win!")
            return 2
        else:
            print("Scissors cut paper! Computer wins!")
            return 1
        
    # or when the player chose Scissors
    else:
        if cpu == 'Paper':
            print("Scissors cut paper! You win!")
            return 2
        else:
            print("Rock crushes Scissors! Computer wins!")
            return 1

# %% [markdown]
# #### 9. Define a function that prints the choice of the computer, the choice of the player and a message that announces who won the current round.
# You should also use this function to update the variables that count the number of rounds that the computer and the player have won. The score of the winner increases by one point. If there is a tie, the score does not increase.

# %%
# did this inside the function above

# %% [markdown]
# #### 10. Now it's time to code the execution of the game using the functions and variables you defined above.
#
# First, create a loop structure that repeats while no player reaches the minimum score necessary to win and the number of rounds is less than the maximum number of rounds to play in a game.
#
# Inside the loop, use the functions and variables above to create the execution of a round: ask for the player's choice, generate the random choice of the computer, show the round results, update the scores, etc.

# %%
def game(n_rounds):
    
    # define variables to store number of wins
    player_score = 0
    cpu_score = 0
    
    # calculate number of rounds to win
    rounds_to_win = (n_rounds + 1) / 2
    
    # store current round
    current_round = 1
    
    print("Welcome to Rock, Paper, Scissors! We will play %d rounds. First player to %d wins is victorious! \n" % (n_rounds, rounds_to_win))
        
    while cpu_score < rounds_to_win and player_score < rounds_to_win and current_round <= n_rounds:
        
        # print the number of the current round
        print("Round #%d" % current_round)
        
        # get cpu and player choice
        cpu = cpu_choice()
        player = player_choice()
        
        # determine who wins the round
        winner = round_winner(player, cpu)
        
        # update the global scores
        if winner == 1:
            cpu_score += 1
        elif winner == 2:
            player_score += 1
        else:
            pass
        
        print("Player %d - %d Computer" % (player_score, cpu_score))
        
        # add a round
        current_round += 1
        
        print("\n")
    
    print("Game over!")
    
    if player_score == cpu_score:
        print("It's a tie! Player %d - %d Computer" % (player_score, cpu_score))
    
    elif player_score > cpu_score:
        print("You are the winner! Player %d - %d Computer" % (player_score, cpu_score))
    
    else:
        print("Sorry, you lose! Player %d - %d Computer" % (player_score, cpu_score))

# uncomment next line to run the game        
game(n_rounds)
# Out:
# Welcome to Rock, Paper, Scissors! We will play 5 rounds. First player to 3 wins is victorious!
#
# Round #1
# Rock, Paper or Scissors?: Blah
# Hmmm not valid, try again please!
# Rock, Paper or Scissors?: Rock
# You choose Rock and Computer chooses Scissors
# Rock crushes Scissors! You win!
# Player 1 - 0 Computer
#
#
# Round #2
# Rock, Paper or Scissors?: Scissors
# You choose Scissors and Computer chooses Scissors
# It's a tie!
# Player 1 - 0 Computer
#
#
# Round #3
# Rock, Paper or Scissors?: Paper
# You choose Paper and Computer chooses Scissors
# Scissors cut paper! Computer wins!
# Player 1 - 1 Computer
#
#
# Round #4
# Rock, Paper or Scissors?: Rock
# You choose Rock and Computer chooses Scissors
# Rock crushes Scissors! You win!
# Player 2 - 1 Computer
#
#
# Round #5
# Rock, Paper or Scissors?: Rock
# You choose Rock and Computer chooses Scissors
# Rock crushes Scissors! You win!
# Player 3 - 1 Computer
#
#
# Game over!
# You are the winner! Player 3 - 1 Computer

# %% [markdown]
# #### 11. Print the winner of the game based on who won more rounds.
# Remember that the game might be tied.

# %%
# did this inside the main game function!

# %% [markdown]
# # NOTES
# - One thing I noted in this exercise is that although I used a fixed number for the rounds to win this value is actually dynamic. It should change as the game goes along because of the possibility of Ties.
# - For example in a game of 7 rounds the first one to 4 wins is the winner, however if by the 5th round there have been 3 wins by the same player and 2 ties, a comeback is already impossible.
# - I tried to think about it and code it into the game, but did not have much time.

# %% [markdown]
# # Bonus: Rock, Paper, Scissors, Lizard & Spock
# ![](images/rpsls.jpg)
#
# In this challenge, you need to improve the previous game by adding two new options. To know more about the rules of the improved version of rock, paper, scissors, check this [link](http://www.samkass.com/theories/RPSSL.html).
#
# In addition, you will also need to improve how the game interacts with the player: the number of rounds to play, which must be an odd number, will be requested to the user until a valid number is entered. Define a new function to make that request.
#
# **Hint**: Try to reuse the code that you already coded in the previous challenge. If your code is efficient, this bonus will only consist of simple modifications to the original game.

# %%
# define new list of possible gestures
gestures = ['Rock', 'Paper', 'Scissors', 'Lizard', 'Spock']

# define function to ask for input of number of rounds to play
def get_rounds():
    
    # set up a while loop that continues if input is invalid and breaks with a correct input.
    while True: 
        
        number = input("How many rounds would you like to play: ")
                
        if number.isdigit():
            
            number = int(number)
        
            if (number % 2) == 0:
                print("%d is not a valid number, please enter an odd number!" % number)
                continue       
            else:
                break
        
        else:
            print("%s is not a number, please enter a number!" % number)
            continue
        
    return number


# define function to get cpu choice
def cpu_choice():
    return gestures[randint(0, 4)]


# define function to get player choice
def player_choice():
    
    # set up a while loop that continues if input is invalid and breaks with a correct input.
    while True: 
        
        # get user input
        choice = input("Rock, Paper, Scissors, Lizard or Spock?: ")
        
        # if the choice is not in the approved list
        if choice not in gestures:
            print("Hmmm not valid, try again please!")
            continue
        
        else:
            break
        
    return choice

# define a function to determine the round winner

def round_winner(player, cpu):
    
    # print both choices
    print("You choose %s and Computer chooses %s" % (player, cpu))
    
    # check for ties
    if player == cpu:
        print("It's a tie!")
        return 0
    
    # check when player chose Rock
    elif player == 'Rock':
        
        if cpu == 'Lizard':
            print("Rock crushes Lizard! You win!")
            return 2
        
        elif cpu == 'Scissors':
            print("Rock crushes Scissors! You win!")
            return 2
                    
        elif cpu == 'Paper':
            print("Paper covers Rock! Computer wins!")
            return 1
        
        else:
            print("Spock vaporizes Rock! Computer wins!")
            return 1
    
    # when the player chose Paper
    elif player == 'Paper':
        
        if cpu == 'Rock':
            print("Paper covers Rock! You win!")
            return 2
        
        elif cpu == 'Spock':
            print("Paper disproves Spock! You win")
            return 2
        
        elif cpu == 'Lizard':
            print("Lizard eats Paper! Computer wins!")
            return 1
        
        else:
            print("Scissors cut Paper! Computer wins!")
            return 1
        
    # when the player chose Scissors
    elif player == 'Scissors':
        
        if cpu == 'Paper':
            print("Scissors cut Paper! You win!")
            return 2
        
        elif cpu == 'Lizard':
            print("Scissors decapitate Lizard! You win!")
            return 2
        
        elif cpu == 'Spock':
            print("Spock smashes Scissors! Computer wins!")
            return 1
        
        else:
            print("Rock crushes Scissors! Computer wins!")
            return 1
    
    # when the player chose Lizard
    elif player == 'Lizard':
        
        if cpu == 'Paper':
            print("Lizard eats Paper! You win!")
            return 2
        
        elif cpu == 'Spock':
            print("Lizard poisons Spock! You win!")
            return 2
        
        elif cpu == 'Rock':
            print("Rock crushes Lizard! Computer wins!")
            return 1
        
        else:
            print("Scissors decapitate Lizard! Computer wins!")
            return 1
    
    # or when the player chose Spock
    else:
        
        if cpu == 'Scissors':
            print("Spock smashes Scissors! You win!")
            return 2
        
        elif cpu == 'Rock':
            print("Spock vaporizes Rock! You win!")
            return 2
        
        elif cpu == 'Paper':
            print("Paper disproves Spock! Computer wins!")
            return 1
        
        else:
            print("Lizard poisons Spock! Computer wins!")
            return 1
        

def bonus_game():
    
    # define variables to store number of wins
    player_score = 0
    cpu_score = 0
    
    print("Welcome to Rock, Paper, Scissors, Lizard, Spock!")
    
    n_rounds = get_rounds()
    
    # calculate number of rounds to win
    rounds_to_win = (n_rounds + 1) / 2
    
    print("We will play %d rounds. First player to %d wins is victorious! \n" % (n_rounds, rounds_to_win))
    
    current_round = 1
        
    while cpu_score < rounds_to_win and player_score < rounds_to_win and current_round <= n_rounds:
        
        # print the number of the current round
        print("Round #%d" % current_round)
        
        # get cpu and player choice
        cpu = cpu_choice()
        player = player_choice()
        
        # determine who wins the round
        winner = round_winner(player, cpu)
        
        # update the global scores
        if winner == 1:
            cpu_score += 1
        elif winner == 2:
            player_score += 1
        else:
            pass
        
        print("Player %d - %d Computer" % (player_score, cpu_score))
        
        # add a round
        current_round += 1
        
        print("\n")
    
    print("Game over!")
    
    if player_score == cpu_score:
        print("It's a tie! Player %d - %d Computer" % (player_score, cpu_score))
    
    elif player_score > cpu_score:
        print("You are the winner! Player %d - %d Computer" % (player_score, cpu_score))
    
    else:
        print("Sorry, you lose! Player %d - %d Computer" % (player_score, cpu_score))

# uncomment this next line to run the bonus game        
bonus_game()
# Out:
# Welcome to Rock, Paper, Scissors, Lizard, Spock!
# How many rounds would you like to play: Lizard
# Lizard is not a number, please enter a number!
# How many rounds would you like to play: 10
# 10 is not a valid number, please enter an odd number!
# How many rounds would you like to play: 7
# We will play 7 rounds. First player to 4 wins is victorious!
#
# Round #1
# Rock, Paper, Scissors, Lizard or Spock?: Lizard
# You choose Lizard and Computer chooses Rock
# Rock crushes Lizard! Computer wins!
# Player 0 - 1 Computer
#
#
# Round #2
# Rock, Paper, Scissors, Lizard or Spock?: Spock
# You choose Spock and Computer chooses Paper
# Paper disproves Spock! Computer wins!
# Player 0 - 2 Computer
#
#
# Round #3
# Rock, Paper, Scissors, Lizard or Spock?: Paper
# You choose Paper and Computer chooses Scissors
# Scissors cut Paper! Computer wins!
# Player 0 - 3 Computer
#
#
# Round #4
# Rock, Paper, Scissors, Lizard or Spock?: Scissors
# You choose Scissors and Computer chooses Rock
# ...

# %% [markdown]
# # NOTES
# - There is likely to be a more elegant mathematical way to determine the winner of each round. I just considered every possibility.
