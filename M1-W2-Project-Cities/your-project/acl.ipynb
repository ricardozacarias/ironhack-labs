# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
acl = pd.read_json('agculturalisboa.json')
acl.head()
acl['date'] = [x[0] if len(x) > 0 else x for x in acl['occurences']]
dates = [x[0] if len(x) > 0 else x for x in acl['occurences'] if x]
dates_list = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in dates]
my = [[x.month, x.year] for x in dates_list]

#dates = [datetime(x) for x in dates]
#print(dates.date.year)

# %%
my
# Out:
# [[2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [8, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
#  [1, 2020],
#  [1, 2020],
#  [2, 2020],
#  [6, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [3, 2020],
#  [7, 2020],
#  [1, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [3, 2020],
#  [3, 2020],
#  [3, 2020],
#  [4, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [3, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [2, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
#  [1, 2020],
#  [2, 2020],
#  [1, 2020],
# ...
