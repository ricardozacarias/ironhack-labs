# %%
import pandas as pd
import glob

# %%
# get data file names
path ='airbnb_data/used/'
filenames = glob.glob(path + "*.csv")
data = pd.concat([pd.read_csv(file) for file in filenames])
data.columns
filenames
# Out:
# ['airbnb_data/used\\airbnb_august18.csv',
#  'airbnb_data/used\\airbnb_august19.csv',
#  'airbnb_data/used\\airbnb_december18.csv',
#  'airbnb_data/used\\airbnb_february19.csv',
#  'airbnb_data/used\\airbnb_january19.csv',
#  'airbnb_data/used\\airbnb_july19.csv',
#  'airbnb_data/used\\airbnb_june19.csv',
#  'airbnb_data/used\\airbnb_march19.csv',
#  'airbnb_data/used\\airbnb_may19.csv',
#  'airbnb_data/used\\airbnb_november18.csv',
#  'airbnb_data/used\\airbnb_october18.csv',
#  'airbnb_data/used\\airbnb_september18.csv']

# %%
data['id'].unique()
print(len(data['id'].unique()))

only_lisbon = data[data['neighbourhood_group'] == 'Lisboa']
only_lisbon.shape
# Out:
# 33006
# (202910, 16)

# %%
data = pd.read_csv(filenames[2])

# %%
data
# Out:
#              id                                       name    host_id  \
# 0         24056                              Linda-a-Velha      95163
# 1         25659  Sunny,  Alfama  Sleeps 3 - Coeur d'Alfama     107347
# 2         26993         Small nice apartment in the center     111686
# 3         28066                              ear the birds     120855
# 4         29138              Room for rent in shared house     125304
# ...         ...                                        ...        ...
# 22645  30889414                          Lisbon Suite Room  230833590
# 22646  30889762                                 Porto Room  230833590
# 22647  30896903                            Wine Inn Studio  193941293
# 22648  30900839            Welcome to real original Lisbon  201644472
# 22649  30902914                        Lisbon garden graca  204428759
#
#       host_name neighbourhood_group  \
# 0      Patrícia              Oeiras
# 1         Ellie              Lisboa
# 2          Hans              Lisboa
# 3         Vania            Azambuja
# 4        Susana              Lisboa
# ...         ...                 ...
# 22645     Elton              Lisboa
# 22646     Elton              Lisboa
# 22647  Wine Inn              Sintra
# 22648     Paulo              Lisboa
# 22649   Cynthia              Lisboa
#
#                                            neighbourhood   latitude  \
# 0            Algs, Linda-a-Velha e Cruz Quebrada-Dafundo  38.717143
# 1                                      Santa Maria Maior  38.711671
# 2                                         Avenidas Novas  38.730747
# 3                                        Aveiras de Cima  39.146542
# 4                                                Areeiro  38.736341
# ...                                                  ...        ...
# 22645                                            Arroios  38.731914
# 22646                                            Arroios  38.733654
# 22647  S.Maria, S.Miguel, S.Martinho, S.Pedro Penaferrim  38.795981
# 22648                                              Beato  38.732784
# 22649                                         So Vicente  38.716376
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0      -9.239672     Private room     84               2                  0
# 1      -9.126964  Entire home/apt     60               2                 96
# 2      -9.148240  Entire home/apt     80               6                  6
# 3      -8.915031     Private room     53               1                  0
# 4      -9.137916     Private room     71               1                  0
# ...          ...              ...    ...             ...                ...
# 22645  -9.134689     Private room     45               2                  0
# 22646  -9.135052     Private room     29               3                  0
# 22647  -9.392228  Entire home/apt     60               1                  0
# 22648  -9.107065  Entire home/apt     49               2                  0
# 22649  -9.127670  Entire home/apt     54               2                  0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0             NaN                NaN                               1
# 1      2018-11-09               1.70                               1
# 2      2018-07-04               0.06                               1
# 3             NaN                NaN                               1
# 4             NaN                NaN                               1
# ...           ...                ...                             ...
# 22645         NaN                NaN                               3
# 22646         NaN                NaN                               3
# 22647         NaN                NaN                               7
# 22648         NaN                NaN                               5
# 22649         NaN                NaN                               1
#
#        availability_365
# 0                   365
# 1                   296
# 2                    56
# 3                   365
# 4                   365
# ...                 ...
# 22645               350
# 22646               365
# 22647               344
# 22648               365
# 22649               352
#
# [22650 rows x 16 columns]
