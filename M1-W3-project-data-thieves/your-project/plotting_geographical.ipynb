# %%
import geopandas
import geoplot

# %% [markdown]
# - Running the examples from geopandas library

# %%
world = geopandas.read_file('C:/Users/Zaca/Documents/Datasets/bra_adm1/BRA_adm1.shp')
geoplot.polyplot(world, figsize=(16, 8))

world
# Out:
#     ID_0  ISO  NAME_0  ID_1               NAME_1 HASC_1  CCN_1 CCA_1  \
# 0     33  BRA  Brazil     1                 Acre  BR.AC      0  None
# 1     33  BRA  Brazil     2              Alagoas  BR.AL      0  None
# 2     33  BRA  Brazil     3               AmapÃ¡  BR.AP      0  None
# 3     33  BRA  Brazil     4             Amazonas  BR.AM      0  None
# 4     33  BRA  Brazil     5                Bahia  BR.BA      0  None
# 5     33  BRA  Brazil     6               CearÃ¡  BR.CE      0  None
# 6     33  BRA  Brazil     7     Distrito Federal  BR.DF      0  None
# 7     33  BRA  Brazil     8      EspÃ­rito Santo  BR.ES      0  None
# 8     33  BRA  Brazil     9               GoiÃ¡s  BR.GO      0  None
# 9     33  BRA  Brazil    10            MaranhÃ£o  BR.MA      0  None
# 10    33  BRA  Brazil    11   Mato Grosso do Sul  BR.MS      0  None
# 11    33  BRA  Brazil    12          Mato Grosso  BR.MT      0  None
# 12    33  BRA  Brazil    13         Minas Gerais  BR.MG      0  None
# ...

# %%
world = world[(world.pop_est>0) & (world.name!="Antarctica")]

world['gdp_per_cap'] = world.gdp_md_est / world.pop_est

world.plot(column='gdp_per_cap', figsize=(16, 8))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-267ae7e94bbf> in <module>
# ----> 1 world = world[(world.pop_est>0) & (world.name!="Antarctica")]
#       2
#       3 world['gdp_per_cap'] = world.gdp_md_est / world.pop_est
#       4
#       5 world.plot(column='gdp_per_cap', figsize=(16, 8))
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'GeoDataFrame' object has no attribute 'pop_est'

# %%
countries = [x for x in world['NAME_EN']]

# %%
print(world['NAME_EN'][world['SOVEREIGNT'] == 'China'])
