# %% [markdown]
# # Cleaning Kaggle Survey Data

# %%
# importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
# locating data
filename = 'multipleChoiceResponses.csv'

# selecting columns
columns_we_care = ['Q3', 'Q6', 'Q9']

# opening data in dataframe
mcr = pd.read_csv(filename, usecols= columns_we_care)

# renaming columns
col_renames = {'Q3': 'country', 'Q6': 'job_title', 'Q9': 'salary'}

mcr.rename(columns= col_renames, inplace= True)
# drop the question row
mcr.drop(index=0, inplace= True)

# drop nans
mcr.dropna(inplace= True)

# %%
# defining list of job titles we are interested in
job_list = ['data scientist',
'software engineer',
 'data analyst',
 'research scientist',
 'business analyst',
 'product manager',
 'project manager',
 'data engineer',
 'statistician',
 'dba',
 'database engineer',
 'machine learning engineer']

# %%
# filtering our data by removing rows in which people declined to answer and if the job is in our list
mcr_jobs = mcr[(mcr['job_title'].str.lower().isin(job_list)) & (mcr['country'].str.contains('I do not wish') == False) & (mcr['salary'].str.contains('I do not wish') == False)]
mcr_jobs
# Out:
#                                                  country           job_title  \
# 3                               United States of America      Data Scientist
# 5                                                  India        Data Analyst
# 10                                               Hungary   Software Engineer
# 12                              United States of America      Data Scientist
# 15                                             Argentina        Data Analyst
# ...                                                  ...                 ...
# 23824  United Kingdom of Great Britain and Northern I...  Research Scientist
# 23833                                             Turkey       Data Engineer
# 23839                                             Turkey        Data Analyst
# 23844                                        Netherlands   Software Engineer
# 23857                                             Turkey   Software Engineer
#
#             salary
# 3         0-10,000
# 5         0-10,000
# 10       20-30,000
# 12     125-150,000
# 15       10-20,000
# ...            ...
# 23824    70-80,000
# 23833     0-10,000
# 23839     0-10,000
# 23844   90-100,000
# 23857    10-20,000
#
# [9196 rows x 3 columns]

# %%
# cleaning the salary values and including only the high end
mcr_jobs['salary'] = mcr_jobs['salary'].str.split('-').str[-1].str.replace(',', '').str.replace('+', '').astype('int32')
# Out:
# C:\Users\Zaca\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
worldwide_salaries_country = mcr_jobs.groupby(by =['country'])['salary'].mean()
worldwide_salaries_country
# Out:
# country
# Argentina                                                34067.796610
# Australia                                                95000.000000
# Austria                                                  53571.428571
# Bangladesh                                               20714.285714
# Belarus                                                  25652.173913
# Belgium                                                  62058.823529
# Brazil                                                   33764.705882
# Canada                                                   80329.457364
# Chile                                                    55000.000000
# China                                                    39038.461538
# Colombia                                                 38767.123288
# Czech Republic                                           38857.142857
# Denmark                                                  83617.021277
# Egypt                                                    17931.034483
# Finland                                                  63285.714286
# France                                                   57084.805654
# Germany                                                  70355.987055
# Greece                                                   24561.403509
# Hong Kong (S.A.R.)                                       87826.086957
# Hungary                                                  33777.777778
# India                                                    30152.788388
# Indonesia                                                16428.571429
# Iran, Islamic Republic of...                             19444.444444
# Ireland                                                  72500.000000
# Israel                                                   99285.714286
# Italy                                                    47237.762238
# Japan                                                    68403.361345
# Kenya                                                    52058.823529
# Malaysia                                                 26511.627907
# Mexico                                                   33697.916667
# Morocco                                                  15263.157895
# Netherlands                                              67873.134328
# New Zealand                                              61060.606061
# Nigeria                                                  18103.448276
# Norway                                                   83611.111111
# Other                                                    31503.579952
# Pakistan                                                 25208.333333
# Peru                                                     27666.666667
# Philippines                                              36296.296296
# Poland                                                   33961.038961
# Portugal                                                 29603.174603
# Republic of Korea                                        54761.904762
# Romania                                                  27567.567568
# Russia                                                   29799.498747
# Singapore                                                68092.105263
# South Africa                                             49802.631579
# South Korea                                              48230.769231
# Spain                                                    42966.101695
# Sweden                                                   67562.500000
# Switzerland                                             116171.875000
# Thailand                                                 31538.461538
# Tunisia                                                  26842.105263
# Turkey                                                   20763.358779
# Ukraine                                                  30325.203252
# United Kingdom of Great Britain and Northern Ireland     74626.168224
# United States of America                                120287.984111
# Viet Nam                                                 18676.470588
# Name: salary, dtype: float64

# %%
salaries_country = worldwide_salaries_country.sort_values(ascending=False)[:10]

plt.figure(figsize=(6, 4))
salary_bar = sns.barplot(salaries_country.index, salaries_country.values, color='royalblue')
plt.xticks(rotation= 90)
plt.xlabel('')
plt.ylabel('Annual Salary (USD)')
plt.tight_layout()
plt.savefig('salary_countries.png', dpi=1200)
# Out:
# C:\Users\Zaca\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.

# %%
worldwide_salaries_jobs = mcr_jobs.groupby(by= ['job_title'])['salary'].mean().sort_values()

worldwide_salaries_jobs

plt.figure(figsize=(6, 4))
salary_bar = sns.barplot(worldwide_salaries_jobs.index, worldwide_salaries_jobs.values, color='royalblue')
plt.xticks(rotation= 90)
plt.xlabel('')
plt.ylabel('Annual Salary (USD)')
plt.tight_layout()
plt.savefig('salary_jobs.png', dpi=1200)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-681-9c3bb99a71ac> in <module>
# ----> 1 worldwide_salaries_jobs.sort_values(ascending= False)
#
# AttributeError: 'AxesSubplot' object has no attribute 'sort_values'

# %%
worldwide = mcr_jobs.groupby(['job_title', 'country']).agg({'salary': 'mean'}).unstack(level= 0)

# %%
worldwide.columns = [x[1] for x in worldwide.columns.values]

# %%
worldwide = worldwide.reset_index()

# %%
worldwide = worldwide.sort_values(by='Business Analyst', ascending= False).reset_index(drop=True).reset_index()
worldwide.rename(columns= {'index': 'Business Analyst Rank'}, inplace=True)

worldwide = worldwide.sort_values(by='Data Analyst', ascending= False).reset_index(drop=True).reset_index()
worldwide.rename(columns= {'index': 'Data Analyst Rank'}, inplace=True)

worldwide = worldwide.sort_values(by='Data Engineer', ascending= False).reset_index(drop=True).reset_index()
worldwide.rename(columns= {'index': 'Data Engineer Rank'}, inplace=True)

worldwide = worldwide.sort_values(by='Data Scientist', ascending= False).reset_index(drop=True).reset_index()
worldwide.rename(columns= {'index': 'Data Scientist Rank'}, inplace=True)

# %%
rankings = worldwide[['country', 'Business Analyst Rank', 'Data Analyst Rank', 'Data Scientist Rank', 'Data Engineer Rank']]
rankings = rankings.sort_values(by='country').reset_index(drop=True)

# %%
worldwide
# Out:
#     Data Scientist Rank  Data Engineer Rank  Data Analyst Rank  \
# 0                     0                  30                 38
# 1                     1                   1                  2
# 2                     2                   2                 14
# 3                     3                   0                 10
# 4                     4                   5                  4
# 5                     5                   8                 12
# 6                     6                   3                 20
# 7                     7                  35                 19
# 8                     8                  50                  1
# 9                     9                  49                  0
# 10                   10                  43                 18
# 11                   11                  11                  6
# 12                   12                   7                 11
# 13                   13                   9                  8
# 14                   14                  23                 16
# 15                   15                  15                 13
# 16                   16                  16                 29
# 17                   17                  18                  3
# 18                   18                  10                 17
# 19                   19                  12                  9
# 20                   20                   6                 15
# 21                   21                  26                 35
# 22                   22                  19                 22
# 23                   23                  52                 27
# 24                   24                  17                 24
# 25                   25                  39                 37
# 26                   26                  34                 26
# 27                   27                  22                 23
# 28                   28                  13                  7
# 29                   29                  42                 50
# 30                   30                  32                 44
# 31                   31                  36                 36
# 32                   32                  38                 40
# 33                   33                  53                 31
# 34                   34                  21                 34
# 35                   35                  28                 32
# 36                   36                  14                 21
# 37                   37                  33                 25
# 38                   38                  37                 28
# 39                   39                  56                 56
# 40                   40                   4                 30
# 41                   41                  44                 49
# 42                   42                  31                 33
# 43                   43                  47                 47
# 44                   44                  40                 48
# 45                   45                  54                 39
# 46                   46                  48                 53
# 47                   47                  51                  5
# 48                   48                  27                 54
# 49                   49                  41                 51
# 50                   50                  24                 45
# 51                   51                  29                 46
# 52                   52                  55                 41
# 53                   53                  46                 42
# 54                   54                  45                 52
# 55                   55                  20                 55
# 56                   56                  25                 43
#
#     Business Analyst Rank                                            country  \
# 0                      40                                              Kenya
# 1                       3                           United States of America
# 2                       1                                        Switzerland
# 3                      11                                             Israel
# 4                       4                                          Australia
# 5                      10                                             Canada
# 6                       9                                            Ireland
# 7                      54                                  Republic of Korea
# 8                       2                                            Denmark
# 9                       5                                             Norway
# 10                     16                                        New Zealand
# 11                     18                                            Germany
# 12                      8  United Kingdom of Great Britain and Northern I...
# 13                     15                                            Finland
# 14                      0                                 Hong Kong (S.A.R.)
# 15                     13                                             Sweden
# 16                     27                                              Chile
# 17                     14                                          Singapore
# 18                     12                                        Netherlands
# 19                      7                                              Japan
# 20                     33                                            Belgium
# 21                     34                                              China
# 22                     19                                             France
# 23                     52                                            Austria
# 24                      6                                       South Africa
# 25                     41                                           Colombia
# 26                     45                                          Argentina
# 27                     20                                              Spain
# 28                     29                                              Italy
# 29                     23                                           Thailand
# 30                     28                                             Mexico
# 31                     24                                              Other
# 32                     49                                               Peru
# 33                     26                                     Czech Republic
# 34                     39                                             Brazil
# 35                     25                                             Poland
# 36                     44                                        South Korea
# 37                     35                                              India
# 38                     17                                           Portugal
# 39                     55                                            Tunisia
# 40                     37                                            Hungary
# 41                     50                                            Belarus
# 42                     30                                             Russia
# 43                     56                                            Ukraine
# 44                     38                                             Greece
# 45                     51                                         Bangladesh
# 46                     42                       Iran, Islamic Republic of...
# 47                     47                                        Philippines
# 48                     36                                            Nigeria
# 49                     46                                             Turkey
# 50                     31                                            Romania
# 51                     22                                           Malaysia
# 52                     53                                              Egypt
# 53                     32                                           Viet Nam
# 54                     43                                            Morocco
# 55                     21                                           Pakistan
# 56                     48                                          Indonesia
#
#     Business Analyst  Data Analyst  Data Engineer  Data Scientist  \
# 0       23333.333333  24230.769231   35000.000000   149000.000000
# 1       86493.055556  81261.127596  126610.169492   136589.195980
# 2      150000.000000  58000.000000  125000.000000   130500.000000
# 3       67500.000000  64000.000000  185000.000000   104259.259259
# 4       84500.000000  71250.000000   93571.428571   103979.591837
# 5       68703.703704  60735.294118   85384.615385    91315.789474
# 6       70000.000000  46363.636364  102500.000000    87000.000000
# 7                NaN  50000.000000   30000.000000    85000.000000
# 8      115000.000000  83750.000000            NaN    84761.904762
# 9       77500.000000  91666.666667            NaN    84666.666667
# 10      50000.000000  54000.000000   20000.000000    79500.000000
# 11      47333.333333  70192.307692   70454.545455    78643.410853
# 12      71111.111111  60740.740741   93214.285714    74620.689655
# 13      60000.000000  68750.000000   81666.666667    73846.153846
# 14     180000.000000  56250.000000   40000.000000    73125.000000
# 15      62000.000000  59000.000000   60000.000000    72580.645161
# 16      35000.000000  32000.000000   56666.666667    71250.000000
# 17      61875.000000  72857.142857   52000.000000    70555.555556
# 18      64285.714286  56000.000000   80000.000000    68560.606061
# 19      72083.333333  66481.481481   65000.000000    66500.000000
# 20      30000.000000  56666.666667   93333.333333    64827.586207
# 21      30000.000000  24912.280702   39583.333333    58819.444444
# 22      46666.666667  44761.904762   51562.500000    57972.027972
# 23               NaN  32500.000000            NaN    53000.000000
# 24      75000.000000  40000.000000   52500.000000    52674.418605
# 25      23333.333333  24545.454545   25000.000000    50869.565217
# 26      17500.000000  33750.000000   30000.000000    50000.000000
# 27      44375.000000  40483.870968   41000.000000    45989.583333
# 28      33333.333333  70000.000000   62272.727273    44307.692308
# 29      40000.000000  17500.000000   20000.000000    40909.090909
# 30      34375.000000  20000.000000   34000.000000    39861.111111
# 31      38783.783784  24545.454545   29107.142857    38272.727273
# 32      10000.000000  22857.142857   25000.000000    38181.818182
# 33      35000.000000  28333.333333            NaN    37272.727273
# 34      25675.675676  25686.274510   42857.142857    37045.454545
# 35      35000.000000  28000.000000   36666.666667    36269.841270
# 36      20000.000000  45000.000000   60000.000000    35333.333333
# 37      29950.000000  34062.500000   30066.666667    34289.617486
# 38      50000.000000  32500.000000   27142.857143    32500.000000
# 39               NaN  10000.000000            NaN    32500.000000
# 40      26666.666667  30000.000000   96666.666667    31428.571429
# 41      10000.000000  18000.000000   16666.666667    31052.631579
# 42      32083.333333  25847.457627   34090.909091    29840.000000
# 43               NaN  19047.619048   13333.333333    29500.000000
# 44      26666.666667  18571.428571   24000.000000    28750.000000
# 45      10000.000000  23333.333333            NaN    28333.333333
# 46      20000.000000  11666.666667   10000.000000    27857.142857
# 47      15000.000000  71250.000000            NaN    26250.000000
# 48      26666.666667  11428.571429   38750.000000    26071.428571
# 49      16000.000000  15882.352941   22000.000000    24090.909091
# 50      30000.000000  20000.000000   40000.000000    23333.333333
# 51      40000.000000  20000.000000   35000.000000    22000.000000
# 52               NaN  22500.000000            NaN    21428.571429
# 53      30000.000000  21250.000000   14000.000000    20833.333333
# 54      20000.000000  12500.000000   15000.000000    20000.000000
# 55      40000.000000  10000.000000   50000.000000    15714.285714
# 56      13333.333333  21250.000000   40000.000000    14000.000000
#
#     Research Scientist  Software Engineer   Statistician
# 0         30000.000000       16250.000000  205000.000000
# 1        109885.057471      136550.000000  111444.444444
# 2        108928.571429      113055.555556  141666.666667
# 3        101000.000000       86500.000000   30000.000000
# 4        100277.777778      114375.000000   73333.333333
# 5         84444.444444       76896.551724   70000.000000
# 6         66666.666667       62000.000000  150000.000000
# 7         36250.000000       76666.666667            NaN
# 8         77857.142857       71000.000000  100000.000000
# 9         93000.000000       76666.666667            NaN
# 10        65000.000000       50000.000000            NaN
# 11        55526.315789       72672.413793   65000.000000
# 12        71447.368421       87500.000000   67142.857143
# 13        36000.000000       54166.666667   50000.000000
# 14        40000.000000       92500.000000            NaN
# 15        61071.428571       71250.000000   80000.000000
# 16        30000.000000       51666.666667   30000.000000
# 17        90000.000000       59687.500000            NaN
# 18        68666.666667       73888.888889            NaN
# 19        72285.714286       68989.361702   55000.000000
# 20        56666.666667       52272.727273   60000.000000
# 21        77419.354839       32521.739130   20000.000000
# 22        52547.169811       75138.888889   41250.000000
# 23        51666.666667       70000.000000   40000.000000
# 24        32000.000000       60000.000000   33333.333333
# 25        35000.000000       42857.142857   20000.000000
# 26        16250.000000       25000.000000            NaN
# 27        46000.000000       37555.555556   33333.333333
# 28        41666.666667       39583.333333   55714.285714
# 29        20000.000000       24000.000000            NaN
# 30        26363.636364       32750.000000   38000.000000
# 31        30319.148936       24358.974359   44600.000000
# 32                 NaN       22500.000000            NaN
# 33        47142.857143       42222.222222            NaN
# 34        43648.648649       32613.636364   20000.000000
# 35        21333.333333       39027.777778   20000.000000
# 36        60833.333333       54137.931034   65000.000000
# 37        33333.333333       25010.482180   21000.000000
# 38        20909.090909       24000.000000   30000.000000
# 39        20000.000000       20000.000000   10000.000000
# 40        30000.000000       25454.545455            NaN
# 41        40000.000000       23529.411765            NaN
# 42        34239.130435       28934.426230   10000.000000
# 43        25000.000000       39130.434783   10000.000000
# 44        25000.000000       22941.176471   20000.000000
# 45                 NaN       18823.529412            NaN
# 46        28000.000000       12000.000000            NaN
# 47        10000.000000       22000.000000   30000.000000
# 48        10000.000000       14166.666667   11666.666667
# 49        24285.714286       19142.857143   13333.333333
# 50        30000.000000       27619.047619   30000.000000
# 51        20000.000000       35000.000000   45000.000000
# 52        10000.000000       12222.222222            NaN
# 53        15000.000000       15200.000000            NaN
# 54        17500.000000       13333.333333   10000.000000
# 55        44444.444444       22000.000000            NaN
# 56        10000.000000       12777.777778   16666.666667

# %%
rankings.to_csv('salary_rankings.csv')

# %%
worldwide

# %%
de_rank = worldwide[['country', 'Data Engineer']].dropna()
da_rank = worldwide[['country', 'Data Analyst']].dropna()
ba_rank = worldwide[['country', 'Business Analyst']].dropna()
ds_rank = worldwide[['country', 'Data Scientist']].dropna()

# %%
de_rank = de_rank.sort_values(by='Data Engineer', ascending= False).reset_index(drop=True)
da_rank = da_rank.sort_values(by='Data Analyst', ascending= False).reset_index(drop=True)
ba_rank = ba_rank.sort_values(by='Business Analyst', ascending= False).reset_index(drop=True)
ds_rank = ds_rank.sort_values(by='Data Scientist', ascending= False).reset_index(drop=True)

da_rank

# %%
de_rank['Data Engineer'] = [x for x in de_rank.index]
da_rank['Data Analyst'] = [x for x in da_rank.index]
ba_rank['Business Analyst'] = [x for x in ba_rank.index]
ds_rank['Data Scientist'] = [x for x in ds_rank.index]

ba_rank

# %%
rankings_clean = pd.DataFrame(worldwide['country'])

# %%
rankings_clean = rankings_clean.merge(de_rank, on='country', how= 'outer').merge(da_rank, on= 'country', how='outer').merge(ba_rank, on= 'country', how='outer').merge(ds_rank, on= 'country', how='outer').sort_values(by= 'country').reset_index(drop=True)

# %%
rankings_clean.to_csv('salary_rankings_clean.csv')
